# %% [markdown]
# ## **Intrdoduction To Open Cv**  And Image Processing

# %%
pip install opencv-python
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ----- ---------------------------------- 5.8/39.5 MB 39.0 MB/s eta 0:00:01
#    --------------- ------------------------ 15.7/39.5 MB 45.0 MB/s eta 0:00:01
#    ------------------------- -------------- 24.9/39.5 MB 43.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 28.0/39.5 MB 36.3 MB/s eta 0:00:01
#    ------------------------------- -------- 31.5/39.5 MB 31.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 34.1/39.5 MB 28.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.9/39.5 MB 25.9 MB/s eta 0:00:01
#    -------------------------------------- - 37.7/39.5 MB 23.3 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 22.1 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 19.9 MB/s eta 0:00:00
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img  = cv2.imread(r'C:\Users\om\Downloads\elephant.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (2150, 3461, 3)

# %%
img
# Out:
# array([[[103, 109, 184],
#         [103, 109, 184],
#         [103, 109, 184],
#         ...,
#         [120, 126, 173],
#         [120, 126, 173],
#         [120, 126, 173]],
#
#        [[103, 109, 184],
#         [103, 109, 184],
#         [103, 109, 184],
#         ...,
#         [120, 126, 173],
#         [120, 126, 173],
#         [120, 126, 173]],
#
#        [[101, 108, 181],
#         [101, 108, 181],
#         [101, 108, 181],
#         ...,
#         [120, 126, 173],
#         [120, 126, 173],
#         [120, 126, 173]],
#
#        ...,
#
#        [[ 34,  51,  78],
#         [ 32,  49,  76],
#         [ 29,  46,  73],
#         ...,
#         [ 40,  57,  84],
#         [ 41,  58,  85],
#         [ 42,  59,  86]],
#
#        [[ 37,  54,  81],
#         [ 33,  50,  77],
#         [ 29,  46,  73],
#         ...,
#         [ 40,  57,  84],
#         [ 41,  58,  85],
#         [ 42,  59,  86]],
#
#        [[ 39,  56,  83],
#         [ 34,  51,  78],
#         [ 28,  45,  72],
# ...

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'C:\Users\om\Downloads\elephant.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (2150, 3461)

# %%
img_gray
# Out:
# array([[131, 131, 131, ..., 139, 139, 139],
#        [131, 131, 131, ..., 139, 139, 139],
#        [129, 129, 129, ..., 139, 139, 139],
#        ...,
#        [ 57,  55,  52, ...,  63,  64,  65],
#        [ 60,  56,  52, ...,  63,  64,  65],
#        [ 62,  57,  51, ...,  63,  64,  65]], dtype=uint8)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap = 'magma')

# %%
plt.imshow(img_gray,cmap = 'grey')

# %%
plt.imshow(img_gray,cmap = 'Accent')

# %%
plt.imshow(img)

# %%
fix_img
# Out:
# array([[[184, 109, 103],
#         [184, 109, 103],
#         [184, 109, 103],
#         ...,
#         [173, 126, 120],
#         [173, 126, 120],
#         [173, 126, 120]],
#
#        [[184, 109, 103],
#         [184, 109, 103],
#         [184, 109, 103],
#         ...,
#         [173, 126, 120],
#         [173, 126, 120],
#         [173, 126, 120]],
#
#        [[181, 108, 101],
#         [181, 108, 101],
#         [181, 108, 101],
#         ...,
#         [173, 126, 120],
#         [173, 126, 120],
#         [173, 126, 120]],
#
#        ...,
#
#        [[ 78,  51,  34],
#         [ 76,  49,  32],
#         [ 73,  46,  29],
#         ...,
#         [ 84,  57,  40],
#         [ 85,  58,  41],
#         [ 86,  59,  42]],
#
#        [[ 81,  54,  37],
#         [ 77,  50,  33],
#         [ 73,  46,  29],
#         ...,
#         [ 84,  57,  40],
#         [ 85,  58,  41],
#         [ 86,  59,  42]],
#
#        [[ 83,  56,  39],
#         [ 78,  51,  34],
#         [ 72,  45,  28],
# ...

# %%
fix_img_1 = cv2.resize(fix_img,(500,367))

# %%
fix_img_1.shape
# Out:
# (367, 500, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
fix_img_2 = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
fix_img_2
# Out:
# array([[[184, 109, 103],
#         [184, 109, 103],
#         [184, 109, 103],
#         ...,
#         [173, 124, 119],
#         [173, 126, 120],
#         [173, 126, 120]],
#
#        [[181, 108, 101],
#         [181, 108, 101],
#         [181, 108, 101],
#         ...,
#         [173, 124, 119],
#         [173, 126, 120],
#         [173, 126, 120]],
#
#        [[180, 107, 100],
#         [180, 107, 100],
#         [180, 107, 100],
#         ...,
#         [173, 124, 119],
#         [173, 126, 120],
#         [173, 126, 120]],
#
#        ...,
#
#        [[ 74,  47,  30],
#         [ 75,  48,  31],
#         [ 78,  51,  34],
#         ...,
#         [ 85,  58,  38],
#         [ 83,  56,  38],
#         [ 85,  58,  40]],
#
#        [[ 76,  49,  32],
#         [ 73,  46,  29],
#         [ 76,  49,  32],
#         ...,
#         [ 84,  57,  36],
#         [ 83,  56,  39],
#         [ 85,  58,  41]],
#
#        [[ 80,  53,  36],
#         [ 71,  44,  27],
#         [ 72,  45,  28],
# ...

# %%
plt.imshow(fix_img_2 )

# %%
img3 = cv2.flip(fix_img_2 ,0)
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img_2,1 )
plt.imshow(img3)

# %%
cv2.imwrite('new gen image.jpg',img3)
# Out:
# True

# %%
pwd
# Out:
# 'C:\\Users\\om'
