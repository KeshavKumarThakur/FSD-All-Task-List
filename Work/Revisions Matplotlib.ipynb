# %% [markdown]
# ## **revisions For matplotlib*

# %%
import matplotlib.pyplot as plt

# %%
# Importing dependecies for matplotlib 
import numpy as np 
import pandas as pd 
import seaborn as sn

# %%
#   Diplaying Plots in matplotlb 
# There are 3  ways to diplays plot in matplotlib 
#1 using the jyupter notebook 
#2 a  script 
# 3 plotting from a Ipython shell

# %%
# %matplotlib inline

# %%
x1 = np.linspace(0,10,100)

# %%
x1
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# create a plot figure 
fig = plt.figure()
plt.plot(x1,np.sin(x1),'-',)
plt.plot(x1,np.cos(x1),'--',color='red')

# %%
# create a plot figure
plt.figure()


# create the first of two panels and set current axis
plt.subplot(5, 2, 4)   # (rows, columns, panel number)
plt.plot(x1, np.sin(x1))


# create the second of two panels and set current axis
plt.subplot(2, 1, 2)   # (rows, columns, panel number)
plt.plot(x1, np.cos(x1));

# %%
print(plt.gca())
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(plt.gcf())
# Out:
# Figure(640x480)

# %%
print(plt.gca())
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
# visualization with pyplot

# %%
plt.plot([1,2,3,4,5,6])
plt.ylabel('Yaxis')
plt.show()

# %%
plt.plot([1,2,3,4,5],[4,5,6,10,12])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# StateMachine Interface 
x = np.linspace(0,2,100)
plt.plot(x,x,label='linear')
plt.plot(x,x**2,label='quadratic')
plt.plot(x,x**3,label='cubic')
plt.xlabel('X labels')
plt.ylabel('y Lable')
plt.legend()
plt.show()

# %%
# working with numpy 
t = np.arange(0.,5.,0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
# Figure ansd plots

# %%
fig.savefig('fig1.png')

# %%
# Line plot

# %%
fig = plt.figure()
ax = plt.axes()
# decalare a variable as x5
x5 = np.linspace(0,10,1000)
# plot the sinusoid plot 
ax.plot(x5,np.sin(x5),'b-')

# %%
# Scatter plot plots  are genertaed usin by dots and circle 
x7 = np.linspace(0,10,30)
y7 = np.sin(x7)
plt.plot(x7,y7,'o',color='black')

# %%
# histogram
#histogram displays frequency .They represented as bars

# %%
data1 = np.random.randn(1000)
plt.hist(data1);

# %%
#   Bar Charts
#Bra charts  disply rectangular bars either in vertical or horizontal . They are used two compare two or more values plt.bar

# %%
data2 = [5.,25.,50.,20.]
plt.bar(range(len(data2)),data2)
plt.show()

# %%
# 19 . Horizontal bar Chart 
data2 =  [5.,25.,50.,20]
plt.barh(range(len(data2)),data2)
plt.show()

# %%
#Error bar chart
